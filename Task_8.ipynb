# %% [markdown]
# <a href="https://colab.research.google.com/github/subi2404/Internship-Python/blob/main/Task_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Image processing

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
img=cv2.imread("/content/img.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x622>

# %%
img=cv2.imread("/content/img.jpg",0)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=500x622>

# %%
cv2.imwrite("save_img.jpg",img)
# Out:
# True
